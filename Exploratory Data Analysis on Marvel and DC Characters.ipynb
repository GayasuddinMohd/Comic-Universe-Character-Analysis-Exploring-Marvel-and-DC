# %% [markdown]
# # DATASET OVERVIEW

# %%
# loading the required liabries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the marvel dataset.
marvel=pd.read_csv("C:\\Users\\abc\\Desktop\\charcters_stats.csv")
marvel
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
# Top 5 records of the dataset.
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
# Looking at the number of rows and columns in the dataset.
marvel.shape
# Out:
# (611, 9)

# %%
# Names of all the columns.
marvel.columns
# Out:
# Index(['Name', 'Alignment', 'Intelligence', 'Strength', 'Speed', 'Durability',
#        'Power', 'Combat', 'Total'],
#       dtype='object')

# %%
# Names of all the columns.
for i in marvel.columns:
    print(i)
# Out:
# Name
# Alignment
# Intelligence
# Strength
# Speed
# Durability
# Power
# Combat
# Total

# %%
# Basic stats about the dataset.
marvel.describe()
# Out:
#        Intelligence    Strength       Speed  Durability       Power  \
# count    611.000000  611.000000  611.000000  611.000000  611.000000
# mean      44.502455   29.083470   27.306056   41.839607   40.312602
# std       32.924722   32.610939   25.760173   36.543849   34.539910
# min        1.000000    1.000000    1.000000    1.000000    0.000000
# 25%        1.000000    1.000000    1.000000    1.000000    0.000000
# 50%       50.000000   10.000000   23.000000   32.000000   37.000000
# 75%       75.000000   53.000000   42.000000   80.000000   67.000000
# max      113.000000  100.000000  100.000000  120.000000  100.000000
#
#            Combat       Total
# count  611.000000  611.000000
# mean    43.206219  226.250409
# std     33.270329  167.324034
# min      1.000000    5.000000
# 25%      1.000000    5.000000
# 50%     50.000000  255.000000
# 75%     70.000000  351.500000
# max    101.000000  581.000000

# %% [markdown]
# # DATA CLEANING

# %%
# Datatypes of all the columns of the dataset.
marvel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          611 non-null    object
#  1   Alignment     608 non-null    object
#  2   Intelligence  611 non-null    int64
#  3   Strength      611 non-null    int64
#  4   Speed         611 non-null    int64
#  5   Durability    611 non-null    int64
#  6   Power         611 non-null    int64
#  7   Combat        611 non-null    int64
#  8   Total         611 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 43.1+ KB

# %%
# Check all the null values in dataset.
marvel.isnull()
# Out:
#       Name  Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0    False      False         False     False  False       False  False
# 1    False      False         False     False  False       False  False
# 2    False      False         False     False  False       False  False
# 3    False      False         False     False  False       False  False
# 4    False      False         False     False  False       False  False
# ..     ...        ...           ...       ...    ...         ...    ...
# 606  False      False         False     False  False       False  False
# 607  False      False         False     False  False       False  False
# 608  False      False         False     False  False       False  False
# 609  False      False         False     False  False       False  False
# 610  False      False         False     False  False       False  False
#
#      Combat  Total
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# ...

# %%
# Sum all the null values in the dataset.
marvel.isnull().sum()
# Out:
# Name            0
# Alignment       3
# Intelligence    0
# Strength        0
# Speed           0
# Durability      0
# Power           0
# Combat          0
# Total           0
# dtype: int64

# %%
# Null values in the Alignment column of the dataset.
marvel.Alignment.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 606    False
# 607    False
# 608    False
# 609    False
# 610    False
# Name: Alignment, Length: 611, dtype: bool

# %%
# Dataset where Alignment column has nulll values.
marvel[marvel.Alignment.isnull()]
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 28   Anti-Venom       NaN            75        60     65          90     85
# 98    Blackwulf       NaN            50        28      8          30     59
# 560   Trickster       NaN             1         1      1           1      0
#
#      Combat  Total
# 28       84    459
# 98       25    200
# 560       1      5

# %%
# types and number of alignment of characters.
marvel.Alignment.value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
# Replace all null values in the Alignment column.
marvel.fillna({'Alignment':'good'},inplace=True)

# %%
# Sum all the null values in the dataset.
marvel.isnull().sum()
# Out:
# Name            0
# Alignment       0
# Intelligence    0
# Strength        0
# Speed           0
# Durability      0
# Power           0
# Combat          0
# Total           0
# dtype: int64

# %% [markdown]
# # Superheroes with the highest speed ?

# %%
# types and number of alignment of characters.
marvel.Alignment.value_counts()
# Out:
# good       435
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
# Make a new dataset of superheroes from the original dataset.
good=marvel[marvel['Alignment']=='good']
good
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
# Glance at the top 5 records of the superheroes.
good.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
# make a dataset from the good dataset which tells us about the Name and Speed of the superheroes.
good_speed=good[['Name','Speed']]
good_speed
# Out:
#                 Name  Speed
# 0            3-D Man     43
# 1             A-Bomb     17
# 2         Abe Sapien     35
# 3           Abin Sur     53
# 6        Adam Monroe     12
# ..               ...    ...
# 604            X-Man     53
# 606     Yellowjacket     12
# 607  Yellowjacket II     35
# 608             Ymir     27
# 609          Zatanna     23
#
# [435 rows x 2 columns]

# %%
# Sort the dataset in descending order of their speed.
good_speed=good_speed.sort_values(by='Speed',ascending=False)
good_speed
# Out:
#                Name  Speed
# 447     Quicksilver    100
# 295         Impulse    100
# 333          Krypto    100
# 85       Black Bolt    100
# 525        Stardust    100
# ..              ...    ...
# 445         Quantum      1
# 127       Bumbleboy      1
# 124  Brother Voodoo      1
# 240     Garbage Man      1
# 264        Guardian      1
#
# [435 rows x 2 columns]

# %%
# Top 5 superheroes with highest speed.
good_speed.head()
# Out:
#             Name  Speed
# 447  Quicksilver    100
# 295      Impulse    100
# 333       Krypto    100
# 85    Black Bolt    100
# 525     Stardust    100

# %% [markdown]
# # Superheroes with the highest Intelligence ?

# %%
# Make a new dataset of superheroes from the original dataset about the Intelligence.
good_intelligence=good[['Name','Intelligence']]
good_intelligence
# Out:
#                 Name  Intelligence
# 0            3-D Man            50
# 1             A-Bomb            38
# 2         Abe Sapien            88
# 3           Abin Sur            50
# 6        Adam Monroe            63
# ..               ...           ...
# 604            X-Man            88
# 606     Yellowjacket            88
# 607  Yellowjacket II            50
# 608             Ymir            50
# 609          Zatanna            75
#
# [435 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Intelligence.
good_intelligence=good_intelligence.sort_values(by='Intelligence',ascending=False)
good_intelligence
# Out:
#                   Name  Intelligence
# 361  Martian Manhunter           100
# 589            Watcher           100
# 306          Jean Grey           100
# 198     Doctor Strange           100
# 440        Professor X           100
# ..                 ...           ...
# 264           Guardian             1
# 262    Green Goblin IV             1
# 261   Green Goblin III             1
# 47             Atom IV             1
# 376          Meteorite             1
#
# [435 rows x 2 columns]

# %%
# Top 5 superheroes with highest intelligence.
good_intelligence.head()
# Out:
#                   Name  Intelligence
# 361  Martian Manhunter           100
# 589            Watcher           100
# 306          Jean Grey           100
# 198     Doctor Strange           100
# 440        Professor X           100

# %% [markdown]
# # Superheroes with the highest Strength ?

# %%
# Make a new dataset of superheroes from the original dataset about the Strength.
good_strength=good[['Name','Strength']]
good_strength
# Out:
#                 Name  Strength
# 0            3-D Man        31
# 1             A-Bomb       100
# 2         Abe Sapien        14
# 3           Abin Sur        90
# 6        Adam Monroe        10
# ..               ...       ...
# 604            X-Man        53
# 606     Yellowjacket        10
# 607  Yellowjacket II        10
# 608             Ymir       100
# 609          Zatanna        10
#
# [435 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Strength.
good_strength=good_strength.sort_values(by='Strength',ascending=False)
good_strength
# Out:
#               Name  Strength
# 600   Wonder Woman       100
# 288           Hulk       100
# 499  Silver Surfer       100
# 537       Superman       100
# 546           Thor       100
# ..             ...       ...
# 442       Psylocke         1
# 445        Quantum         1
# 175   Danny Cooper         1
# 173         Cypher         1
# 162   Colossal Boy         1
#
# [435 rows x 2 columns]

# %%
# Top 5 superheroes with highest Strength.
good_strength.head()
# Out:
#               Name  Strength
# 600   Wonder Woman       100
# 288           Hulk       100
# 499  Silver Surfer       100
# 537       Superman       100
# 546           Thor       100

# %% [markdown]
# # Who is the most durable superhero ?

# %%
# Make a new dataset of superheroes from the original dataset about the Durability.
good_durability=good[['Name','Durability']]
good_durability
# Out:
#                 Name  Durability
# 0            3-D Man          32
# 1             A-Bomb          80
# 2         Abe Sapien          42
# 3           Abin Sur          64
# 6        Adam Monroe         100
# ..               ...         ...
# 604            X-Man          95
# 606     Yellowjacket          28
# 607  Yellowjacket II          28
# 608             Ymir         100
# 609          Zatanna          28
#
# [435 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Durability.
good_durability=good_durability.sort_values(by='Durability',ascending=False)
good_durability
# Out:
#                 Name  Durability
# 525         Stardust         110
# 499    Silver Surfer         101
# 417             Nova         101
# 185          Deadman         100
# 267          Hancock         100
# ..               ...         ...
# 466          Ripcord           1
# 468         Robin II           1
# 343      Liz Sherman           1
# 246        Giant-Man           1
# 287  Howard the Duck           1
#
# [435 rows x 2 columns]

# %%
# Top 5 superheroes with highest Durability.
good_durability=good_durability.head()
good_durability
# Out:
#               Name  Durability
# 525       Stardust         110
# 499  Silver Surfer         101
# 417           Nova         101
# 185        Deadman         100
# 267        Hancock         100

# %%
# Name of the 5 most durable superheroes.
x=list(good_durability['Name'])
x
# Out:
# ['Stardust', 'Silver Surfer', 'Nova', 'Deadman', 'Hancock']

# %%
# Count of the durability of the top 5 superheroes.
y=list(good_durability['Durability'])
y
# Out:
# [110, 101, 101, 100, 100]

# %%
# Bar-plot for top 5 superheroes with highest Durability..
plt.figure(figsize=(10,5))
plt.bar(x,y,color=['red','yellow','green','black','pink'],ec='black',lw=1)
plt.grid(True)
plt.title("Durability of the Superheroes",fontsize=15)
plt.xlabel('Name of the Superheroes',fontsize=13)
plt.ylabel('Count of the Durability',fontsize=13)
plt.show()

# %% [markdown]
# # Superheroes with the highest Power ?

# %%
# Make a new dataset of superheroes from the original dataset about the Power.
good_power=good[['Name','Power']]
good_power
# Out:
#                 Name  Power
# 0            3-D Man     25
# 1             A-Bomb     17
# 2         Abe Sapien     35
# 3           Abin Sur     84
# 6        Adam Monroe     71
# ..               ...    ...
# 604            X-Man     92
# 606     Yellowjacket     12
# 607  Yellowjacket II     31
# 608             Ymir     83
# 609          Zatanna    100
#
# [435 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Power.
good_power=good_power.sort_values(by='Power',ascending=False)
good_power
# Out:
#              Name  Power
# 609       Zatanna    100
# 487   Shadow King    100
# 433       Phoenix    100
# 419     Offspring    100
# 418          Nova    100
# ..            ...    ...
# 255    Goliath IV      0
# 253    Goliath II      0
# 39        Arsenal      0
# 462  Renata Soliz      0
# 51          Aztar      0
#
# [435 rows x 2 columns]

# %%
# Top 5 superheroes with highest Power.
good_power=good_power.head()
good_power
# Out:
#             Name  Power
# 609      Zatanna    100
# 487  Shadow King    100
# 433      Phoenix    100
# 419    Offspring    100
# 418         Nova    100

# %% [markdown]
# # Which superhero has the highest Combat ?

# %%
# Make a new dataset of superheroes from the original dataset about the Combat.
good_combat=good[['Name','Combat']]
good_combat
# Out:
#                 Name  Combat
# 0            3-D Man      52
# 1             A-Bomb      64
# 2         Abe Sapien      85
# 3           Abin Sur      65
# 6        Adam Monroe      64
# ..               ...     ...
# 604            X-Man      84
# 606     Yellowjacket      14
# 607  Yellowjacket II      28
# 608             Ymir      28
# 609          Zatanna      56
#
# [435 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Combat.
good_combat=good_combat.sort_values(by='Combat',ascending=False)
good_combat
# Out:
#              Name  Combat
# 36           Ares     101
# 147       Century     100
# 281      Hercules     100
# 489     Shang-Chi     100
# 94    Black Widow     100
# ..            ...     ...
# 439     Power Man       1
# 442      Psylocke       1
# 136  Captain Epic       1
# 445       Quantum       1
# 264      Guardian       1
#
# [435 rows x 2 columns]

# %%
# Top 5 records of the dataset.
good_combat.head()
# Out:
#             Name  Combat
# 36          Ares     101
# 147      Century     100
# 281     Hercules     100
# 489    Shang-Chi     100
# 94   Black Widow     100

# %%
# Name of the 5 superheroes with highest combat.
x=list(good_combat['Name'][0:5])
x
# Out:
# ['Ares', 'Century', 'Hercules', 'Shang-Chi', 'Black Widow']

# %%
# Count of the combat of the top 5 superheroes.
y=list(good_combat['Combat'][0:5])
y
# Out:
# [101, 100, 100, 100, 100]

# %%
# Bar-plot for top 5 superheroes with highest Combat.
plt.figure(figsize=(10,5))
plt.bar(x,y,color=['lawngreen','peru','tomato','deeppink','blue'],ec='black',lw=1)
plt.grid(True)
plt.title("Combat of the Superheroes",fontsize=15)
plt.xlabel('Name of the Superheroes',fontsize=13)
plt.ylabel('Count of the Combat',fontsize=13)
plt.show()

# %% [markdown]
# # Who is the best superhero ?

# %%
# Make a new dataset of superheroes from the original dataset about the Total column.
good_total=good[['Name','Total']]
good_total
# Out:
#                 Name  Total
# 0            3-D Man    233
# 1             A-Bomb    316
# 2         Abe Sapien    299
# 3           Abin Sur    406
# 6        Adam Monroe    320
# ..               ...    ...
# 604            X-Man    465
# 606     Yellowjacket    164
# 607  Yellowjacket II    182
# 608             Ymir    388
# 609          Zatanna    292
#
# [435 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Total column.
good_total=good_total.sort_values(by='Total',ascending=False)
good_total
# Out:
#                   Name  Total
# 361  Martian Manhunter    581
# 537           Superman    579
# 525           Stardust    568
# 546               Thor    546
# 536          Supergirl    544
# ..                 ...    ...
# 127          Bumbleboy      5
# 405              Namor      5
# 124     Brother Voodoo      5
# 409    Nathan Petrelli      5
# 421         Omniscient      5
#
# [435 rows x 2 columns]

# %%
# Top 5 superheroes with highest Total.
good_total=good_total.head()
good_total
# Out:
#                   Name  Total
# 361  Martian Manhunter    581
# 537           Superman    579
# 525           Stardust    568
# 546               Thor    546
# 536          Supergirl    544

# %%
# Name of the 5 superheroes with highest Total.
x=list(good_total['Name'])
x
# Out:
# ['Martian Manhunter', 'Superman', 'Stardust', 'Thor', 'Supergirl']

# %%
# Count of the Total of the top 5 superheroes.
y=list(good_total['Total'])
y
# Out:
# [581, 579, 568, 546, 544]

# %%
# Bar-plot for top 5 superheroes with highest Total.
plt.figure(figsize=(10,5))
plt.bar(x,y,color=['purple','slategray','navy','forestgreen','gold'],ec='black',lw=1)
plt.grid(True)
plt.title("Total of the Superheroes",fontsize=15)
plt.xlabel('Name of the Superheroes',fontsize=13)
plt.ylabel('Count of the Total',fontsize=13)
plt.show()

# %% [markdown]
# # Supervillains with the highest speed ?

# %%
# Make a new dataset of supervillains from the original dataset.
bad=marvel[marvel['Alignment']=='bad']
bad
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4       Abomination       bad            63        80     53          90
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# ...

# %%
# Glance at the top 5 records of the supervillains.
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
# make a dataset from the bad dataset which tells us about the Name and Speed of the supervillains.
bad_speed=bad[['Name','Speed']]
bad_speed
# Out:
#                Name  Speed
# 4       Abomination     53
# 5           Abraxas     83
# 11       Air-Walker    100
# 16            Amazo    100
# 17             Ammo      1
# ..              ...    ...
# 586            Warp     23
# 590       Weapon XI      1
# 593  Willis Stryker     23
# 605     Yellow Claw      1
# 610            Zoom    100
#
# [165 rows x 2 columns]

# %%
# Sort the dataset in descending order of their speed.
bad_speed=bad_speed.sort_values(by='Speed',ascending=False)
bad_speed
# Out:
#                 Name  Speed
# 610             Zoom    100
# 11        Air-Walker    100
# 16             Amazo    100
# 535   Superboy-Prime    100
# 242      General Zod     96
# ..               ...    ...
# 256  Granny Goodness      1
# 254      Goliath III      1
# 503         Siren II      1
# 154      Cheetah III      1
# 153       Cheetah II      1
#
# [165 rows x 2 columns]

# %%
# Top 5 supervillains with highest speed.
bad_speed.head()
# Out:
#                Name  Speed
# 610            Zoom    100
# 11       Air-Walker    100
# 16            Amazo    100
# 535  Superboy-Prime    100
# 242     General Zod     96

# %% [markdown]
# # Who is the most intelligent supervillain ?

# %%
# Make a new dataset of supervillains from the original dataset about the Intelligence.
bad_intelligence=bad[['Name','Intelligence']]
bad_intelligence
# Out:
#                Name  Intelligence
# 4       Abomination            63
# 5           Abraxas            88
# 11       Air-Walker            50
# 16            Amazo            75
# 17             Ammo             1
# ..              ...           ...
# 586            Warp            38
# 590       Weapon XI             1
# 593  Willis Stryker            38
# 605     Yellow Claw             1
# 610            Zoom            50
#
# [165 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Intelligence.
bad_intelligence=bad_intelligence.sort_values(by='Intelligence',ascending=False)
bad_intelligence
# Out:
#                 Name  Intelligence
# 386  Mister Mxyzptlk           113
# 338       Lex Luthor           100
# 336           Leader           100
# 122         Brainiac           100
# 194      Doctor Doom           100
# ..               ...           ...
# 460      Redeemer II             1
# 154      Cheetah III             1
# 153       Cheetah II             1
# 152        Cheetah I             1
# 461     Redeemer III             1
#
# [165 rows x 2 columns]

# %%
# Top 5 supervillains with highest intelligence.
bad_intelligence.head()
# Out:
#                 Name  Intelligence
# 386  Mister Mxyzptlk           113
# 338       Lex Luthor           100
# 336           Leader           100
# 122         Brainiac           100
# 194      Doctor Doom           100

# %%
# Names of the top 5 supervillains with highest Intelligence. 
x=list(bad_intelligence['Name'][0:5])
x
# Out:
# ['Mister Mxyzptlk', 'Lex Luthor', 'Leader', 'Brainiac', 'Doctor Doom']

# %%
# Count of the Intelligenceof the top 5 supervillains.
y=list(bad_intelligence['Intelligence'][0:5])
y
# Out:
# [113, 100, 100, 100, 100]

# %%
# Bar-plot for top 5 supervillains with highest Intelligence.
plt.figure(figsize=(10,5))
plt.bar(x,y,color=['black','rosybrown','red','orangered','salmon'],ec='black',lw=1)
plt.grid(True)
plt.title("Intelligence of the Supervillains",fontsize=15)
plt.xlabel('Name of the Supervillains',fontsize=13)
plt.ylabel('Count of the Intelligence',fontsize=13)
plt.show()

# %% [markdown]
# # Supervillains with the highest Strength ?

# %%
# Make a new dataset of supervillains from the original dataset about the Strength.
bad_strength=bad[['Name','Strength']]
bad_strength
# Out:
#                Name  Strength
# 4       Abomination        80
# 5           Abraxas       100
# 11       Air-Walker        85
# 16            Amazo       100
# 17             Ammo         1
# ..              ...       ...
# 586            Warp        10
# 590       Weapon XI         1
# 593  Willis Stryker        16
# 605     Yellow Claw         1
# 610            Zoom        10
#
# [165 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Strength.
bad_strength=bad_strength.sort_values(by='Strength',ascending=False)
bad_strength
# Out:
#                  Name  Strength
# 180          Darkseid       100
# 84         Black Adam       100
# 535    Superboy-Prime       100
# 542            Thanos       100
# 5             Abraxas       100
# ..                ...       ...
# 335  Lady Deathstrike         1
# 334     Lady Bullseye         1
# 168             Curse         1
# 109       Bloodwraith         1
# 169            Cy-Gor         1
#
# [165 rows x 2 columns]

# %%
# Top 5 supervillains with highest Strength.
bad_strength.head()
# Out:
#                Name  Strength
# 180        Darkseid       100
# 84       Black Adam       100
# 535  Superboy-Prime       100
# 542          Thanos       100
# 5           Abraxas       100

# %% [markdown]
# # Who is the most durable supervillain ?

# %%
# Make a new dataset of supervillains from the original dataset about the Durability.
bad_durability=bad[['Name','Durability']]
bad_durability
# Out:
#                Name  Durability
# 4       Abomination          90
# 5           Abraxas          99
# 11       Air-Walker          85
# 16            Amazo         100
# 17             Ammo           1
# ..              ...         ...
# 586            Warp          28
# 590       Weapon XI           1
# 593  Willis Stryker          28
# 605     Yellow Claw           1
# 610            Zoom          28
#
# [165 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Durability.
bad_durability=bad_durability.sort_values(by='Durability',ascending=False)
bad_durability
# Out:
#                 Name  Durability
# 201         Doomsday         120
# 180         Darkseid         100
# 345             Lobo         100
# 171  Cyborg Superman         100
# 84        Black Adam         100
# ..               ...         ...
# 420        Omega Red           1
# 75     Billy Kincaid           1
# 425        Overtkill           1
# 452    Razor-Fist II           1
# 79       Bird-Man II           1
#
# [165 rows x 2 columns]

# %%
# Top 5 supervillains with highest Durability.
bad_durability=bad_durability.head()
bad_durability
# Out:
#                 Name  Durability
# 201         Doomsday         120
# 180         Darkseid         100
# 345             Lobo         100
# 171  Cyborg Superman         100
# 84        Black Adam         100

# %%
# Name of the 5 most durable supervillains.
x=list(bad_durability['Name'])
x
# Out:
# ['Doomsday', 'Darkseid', 'Lobo', 'Cyborg Superman', 'Black Adam']

# %%
# Count of the durability of the top 5 supervillains.
y=list(bad_durability['Durability'])
y
# Out:
# [120, 100, 100, 100, 100]

# %%
# Bar-plot for top 5 supervillains with highest durability.
plt.figure(figsize=(10,5))
plt.bar(x,y,color=['purple','yellow','green','black','red'],ec='black',lw=1)
plt.grid(True)
plt.title("Durability of the Supervillains",fontsize=15)
plt.xlabel('Name of the Supervillains',fontsize=13)
plt.ylabel('Count of the Durability',fontsize=13)
plt.show()

# %% [markdown]
# # Supervillains with the highest Power ?

# %%
# Make a new dataset of supervillains from the original dataset about the Power.
bad_power=bad[['Name','Power']]
bad_power
# Out:
#                Name  Power
# 4       Abomination     55
# 5           Abraxas    100
# 11       Air-Walker    100
# 16            Amazo    100
# 17             Ammo      0
# ..              ...    ...
# 586            Warp     63
# 590       Weapon XI      0
# 593  Willis Stryker     41
# 605     Yellow Claw      0
# 610            Zoom     72
#
# [165 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Power.
bad_power=bad_power.sort_values(by='Power',ascending=False)
bad_power
# Out:
#                  Name  Power
# 564            Ultron    100
# 422         Onslaught    100
# 180          Darkseid    100
# 501          Sinestro    100
# 386   Mister Mxyzptlk    100
# ..                ...    ...
# 335  Lady Deathstrike      0
# 154       Cheetah III      0
# 103          Blizzard      0
# 197    Doctor Octopus      0
# 256   Granny Goodness      0
#
# [165 rows x 2 columns]

# %%
# Top 5 supervillains with highest Power.
bad_power=bad_power.head()
bad_power
# Out:
#                 Name  Power
# 564           Ultron    100
# 422        Onslaught    100
# 180         Darkseid    100
# 501         Sinestro    100
# 386  Mister Mxyzptlk    100

# %% [markdown]
# # Supervillains with the highest Combat ?

# %%
# Make a new dataset of supervillains from the original dataset about the Combat.
bad_combat=bad[['Name','Combat']]
bad_combat
# Out:
#                Name  Combat
# 4       Abomination      95
# 5           Abraxas      56
# 11       Air-Walker      40
# 16            Amazo     100
# 17             Ammo       1
# ..              ...     ...
# 586            Warp      50
# 590       Weapon XI       1
# 593  Willis Stryker      60
# 605     Yellow Claw       1
# 610            Zoom      28
#
# [165 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Combat.
bad_combat=bad_combat.sort_values(by='Combat',ascending=False)
bad_combat
# Out:
#              Name  Combat
# 475    Sabretooth     100
# 16          Amazo     100
# 449  Ra's Al Ghul     100
# 464     Rick Flag      95
# 180      Darkseid      95
# ..            ...     ...
# 460   Redeemer II       1
# 461  Redeemer III       1
# 83   Black Abbott       1
# 78       Bird-Man       1
# 79    Bird-Man II       1
#
# [165 rows x 2 columns]

# %%
# Top 5 supervillains who have the highest combat.
bad_combat.head()
# Out:
#              Name  Combat
# 475    Sabretooth     100
# 16          Amazo     100
# 449  Ra's Al Ghul     100
# 464     Rick Flag      95
# 180      Darkseid      95

# %% [markdown]
# # Who is the best Supervillain ?

# %%
# Make a new dataset of supervillains from the original dataset about the Total column.
bad_total=bad[['Name','Total']]
bad_total
# Out:
#                Name  Total
# 4       Abomination    436
# 5           Abraxas    526
# 11       Air-Walker    460
# 16            Amazo    575
# 17             Ammo      5
# ..              ...    ...
# 586            Warp    212
# 590       Weapon XI      5
# 593  Willis Stryker    206
# 605     Yellow Claw      5
# 610            Zoom    288
#
# [165 rows x 2 columns]

# %%
# Sort the dataset in descending order of their Total column.
bad_total=bad_total.sort_values(by='Total',ascending=False)
bad_total
# Out:
#                Name  Total
# 535  Superboy-Prime    579
# 242     General Zod    579
# 16            Amazo    575
# 203        Dormammu    546
# 201        Doomsday    545
# ..              ...    ...
# 103        Blizzard      5
# 349   Luke Campbell      5
# 181        Darkside      5
# 390          Moloch      5
# 254     Goliath III      5
#
# [165 rows x 2 columns]

# %%
# Top 5 supervillains with highest Total.
bad_total=bad_total.head()
bad_total
# Out:
#                Name  Total
# 535  Superboy-Prime    579
# 242     General Zod    579
# 16            Amazo    575
# 203        Dormammu    546
# 201        Doomsday    545

# %%
# Name of the 5 supervillains with highest Total.
x=list(bad_total['Name'])
x
# Out:
# ['Superboy-Prime', 'General Zod', 'Amazo', 'Dormammu', 'Doomsday']

# %%
# Count of the Total of the top 5 supervillains.
y=list(bad_total['Total'])
y
# Out:
# [579, 579, 575, 546, 545]

# %%
# Bar-plot for top 5 supervillains with highest Total.
plt.figure(figsize=(10,5))
plt.bar(x,y,color=['bisque','darkorange','lawngreen','olive','crimson'],ec='black',lw=1)
plt.grid(True)
plt.title("Total of the Supervillains",fontsize=15)
plt.xlabel('Name of the Supervillains',fontsize=13)
plt.ylabel('Count of the Total',fontsize=13)
plt.show()

# %% [markdown]
# # What range of Intelligence most of the characters have ?

# %%
# Intelligence column of the dataset.
marvel['Intelligence']
# Out:
# 0      50
# 1      38
# 2      88
# 3      50
# 4      63
#        ..
# 606    88
# 607    50
# 608    50
# 609    75
# 610    50
# Name: Intelligence, Length: 611, dtype: int64

# %%
# Displot for the Intelligence column of the dataset.
sns.displot(marvel['Intelligence'],color="purple",kde=True)
plt.title("INTELLIGENCE",fontsize=15)
plt.ylabel('Number of the Characters',fontsize=13)
plt.xlabel('Intelligency of the Characters',fontsize=13)
plt.grid(True)
plt.show()

# %% [markdown]
# # What range of Strength most of the characters have ?

# %%
# Strength column of the dataset.
marvel['Strength']
# Out:
# 0       31
# 1      100
# 2       14
# 3       90
# 4       80
#       ...
# 606     10
# 607     10
# 608    100
# 609     10
# 610     10
# Name: Strength, Length: 611, dtype: int64

# %%
# Displot for the Strength column of the dataset.
sns.displot(marvel['Strength'],color="lawngreen",kde=True)
plt.title("STRENGTH",fontsize=15)
plt.ylabel('Number of the Characters',fontsize=13)
plt.xlabel('Strength of the Characters',fontsize=13)
plt.grid(True)
plt.show()

# %% [markdown]
# # What range of Speed most of the characters have ?

# %%
# Speed column of the dataset.
marvel['Speed']
# Out:
# 0       43
# 1       17
# 2       35
# 3       53
# 4       53
#       ...
# 606     12
# 607     35
# 608     27
# 609     23
# 610    100
# Name: Speed, Length: 611, dtype: int64

# %%
# Displot for the Speed column of the dataset.
sns.displot(marvel['Speed'],color="red",kde=True)
plt.title("SPEED",fontsize=15)
plt.ylabel('Number of the Characters',fontsize=13)
plt.xlabel('Speed of the Characters',fontsize=13)
plt.grid(True)
plt.show()

# %% [markdown]
# # What range of Durability most of the characters have ?

# %%
# Durability column of the dataset.
marvel['Durability']
# Out:
# 0       32
# 1       80
# 2       42
# 3       64
# 4       90
#       ...
# 606     28
# 607     28
# 608    100
# 609     28
# 610     28
# Name: Durability, Length: 611, dtype: int64

# %%
# Displot for the Durabiity column of the dataset.
sns.displot(marvel['Durability'],color="blue",kde=True)
plt.title("DURABILITY",fontsize=15)
plt.ylabel('Number of the Characters',fontsize=13)
plt.xlabel('Durability of the Characters',fontsize=13)
plt.grid(True)
plt.show()

# %% [markdown]
# # What range of Power most of the characters have ?

# %%
# Power column of the dataset.
marvel['Power']
# Out:
# 0       25
# 1       17
# 2       35
# 3       84
# 4       55
#       ...
# 606     12
# 607     31
# 608     83
# 609    100
# 610     72
# Name: Power, Length: 611, dtype: int64

# %%
# Displot for the Power column of the dataset.
sns.displot(marvel['Power'],color="yellow",kde=True)
plt.title("POWER",fontsize=15)
plt.ylabel('Number of the Characters',fontsize=13)
plt.xlabel('Power of the Characters',fontsize=13)
plt.grid(True)
plt.show()

# %% [markdown]
# # What range of Combat most of the characters have ?

# %%
# Combat column of the dataset.
marvel['Combat']
# Out:
# 0      52
# 1      64
# 2      85
# 3      65
# 4      95
#        ..
# 606    14
# 607    28
# 608    28
# 609    56
# 610    28
# Name: Combat, Length: 611, dtype: int64

# %%
# Displot for the Combat column of the dataset.
sns.displot(marvel['Combat'],color="maroon",kde=True)
plt.title("COMBAT",fontsize=15)
plt.ylabel('Number of the Characters',fontsize=13)
plt.xlabel('Combat of the Characters',fontsize=13)
plt.grid(True)
plt.show()

# %% [markdown]
# # What range of Total most of the characters have ?

# %%
# Total column of the dataset.
marvel['Total']
# Out:
# 0      233
# 1      316
# 2      299
# 3      406
# 4      436
#       ...
# 606    164
# 607    182
# 608    388
# 609    292
# 610    288
# Name: Total, Length: 611, dtype: int64

# %%
# Displot for the Total column of the dataset.
sns.displot(marvel['Total'],color="magenta",kde=True)
plt.title("TOTAL",fontsize=15)
plt.ylabel('Number of the Characters',fontsize=13)
plt.xlabel('Total of the Characters',fontsize=13)
plt.grid(True)
plt.show()

# %% [markdown]
# # Which allignment of character have the highest value of Total ?

# %%
# List of all values in total column of good datatset.
good=list(good['Total'])
good
# Out:
# [233,
#  316,
#  299,
#  406,
#  320,
#  5,
#  5,
#  61,
#  388,
#  386,
#  5,
#  162,
#  5,
#  5,
#  245,
#  210,
#  389,
#  225,
#  184,
#  459,
#  103,
#  360,
#  418,
#  5,
#  268,
#  435,
#  186,
#  314,
#  5,
#  5,
#  363,
#  5,
#  179,
#  5,
#  5,
#  5,
#  5,
#  329,
#  233,
#  5,
#  290,
#  232,
#  5,
#  5,
#  5,
#  306,
#  5,
#  238,
#  324,
#  296,
#  334,
#  5,
#  346,
#  317,
#  165,
#  457,
#  467,
#  375,
#  178,
#  255,
#  5,
#  161,
#  5,
#  325,
#  482,
#  5,
#  5,
#  227,
#  5,
#  264,
#  287,
#  335,
#  279,
#  5,
#  200,
#  302,
#  5,
#  265,
#  225,
#  320,
#  5,
#  5,
#  5,
#  349,
#  5,
#  222,
#  5,
#  356,
#  5,
#  5,
#  243,
#  253,
#  5,
#  206,
#  5,
#  155,
#  395,
#  232,
#  379,
#  319,
#  5,
#  373,
#  5,
#  5,
#  480,
#  363,
#  5,
#  5,
#  5,
#  5,
#  246,
#  5,
#  459,
#  5,
#  281,
#  374,
#  260,
#  5,
#  314,
#  5,
#  5,
#  405,
#  5,
#  5,
#  5,
#  218,
#  391,
#  306,
#  5,
#  272,
#  5,
#  132,
#  295,
#  323,
#  237,
#  239,
#  178,
#  270,
# ...

# %%
# List of all values in total column of bad datatset.
bad=list(bad['Total'])
bad
# Out:
# [436,
#  526,
#  460,
#  575,
#  5,
#  5,
#  381,
#  496,
#  5,
#  493,
#  288,
#  370,
#  366,
#  5,
#  227,
#  5,
#  5,
#  5,
#  5,
#  525,
#  305,
#  323,
#  191,
#  5,
#  5,
#  220,
#  309,
#  424,
#  5,
#  5,
#  416,
#  246,
#  311,
#  451,
#  194,
#  266,
#  5,
#  5,
#  5,
#  5,
#  5,
#  5,
#  5,
#  540,
#  506,
#  5,
#  238,
#  289,
#  461,
#  429,
#  36,
#  5,
#  545,
#  372,
#  546,
#  449,
#  316,
#  217,
#  327,
#  370,
#  5,
#  512,
#  535,
#  5,
#  341,
#  579,
#  352,
#  257,
#  298,
#  5,
#  5,
#  272,
#  281,
#  268,
#  5,
#  272,
#  379,
#  5,
#  290,
#  296,
#  417,
#  198,
#  287,
#  241,
#  356,
#  256,
#  283,
#  5,
#  5,
#  236,
#  174,
#  227,
#  278,
#  282,
#  486,
#  418,
#  5,
#  371,
#  450,
#  531,
#  373,
#  498,
#  398,
#  445,
#  384,
#  254,
#  277,
#  5,
#  5,
#  339,
#  315,
#  268,
#  256,
#  306,
#  5,
#  505,
#  5,
#  200,
#  213,
#  227,
#  222,
#  152,
#  329,
#  5,
#  148,
#  210,
#  5,
#  5,
#  360,
#  264,
#  160,
#  351,
#  215,
#  258,
# ...

# %%
# Dataset of neutral characters.
neutral=marvel[marvel['Alignment']=='neutral']
neutral
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 82        Bizarro   neutral            75        95    100         100     95
# 186      Deadpool   neutral            50        15     30         100    100
# 189   Deathstroke   neutral            75        30     35         100     36
# 238      Galactus   neutral           100       100     83         100    100
# 318    Juggernaut   neutral            44       100     42         100     74
# 357       Man-Bat   neutral            38        18     50          70     33
# 451         Raven   neutral            50        10     29          70     62
# 454      Red Hood   neutral            75        12     23          28     24
# 477       Sandman   neutral            50        75     47          97     62
# 544  The Comedian   neutral            63        14     17          10     12
# 557          Toad   neutral            50        34     58          56     49
#
#      Combat  Total
# ...

# %%
# List of all values in total column of neutral datatset.
neutral=list(neutral['Total'])
neutral
# Out:
# [550, 395, 366, 553, 430, 239, 261, 257, 387, 196, 275]

# %%
# create a data variable.
data=list([good,bad,neutral])
data
# Out:
# [[233,
#   316,
#   299,
#   406,
#   320,
#   5,
#   5,
#   61,
#   388,
#   386,
#   5,
#   162,
#   5,
#   5,
#   245,
#   210,
#   389,
#   225,
#   184,
#   459,
#   103,
#   360,
#   418,
#   5,
#   268,
#   435,
#   186,
#   314,
#   5,
#   5,
#   363,
#   5,
#   179,
#   5,
#   5,
#   5,
#   5,
#   329,
#   233,
#   5,
#   290,
#   232,
#   5,
#   5,
#   5,
#   306,
#   5,
#   238,
#   324,
#   296,
#   334,
#   5,
#   346,
#   317,
#   165,
#   457,
#   467,
#   375,
#   178,
#   255,
#   5,
#   161,
#   5,
#   325,
#   482,
#   5,
#   5,
#   227,
#   5,
#   264,
#   287,
#   335,
#   279,
#   5,
#   200,
#   302,
#   5,
#   265,
#   225,
#   320,
#   5,
#   5,
#   5,
#   349,
#   5,
#   222,
#   5,
#   356,
#   5,
#   5,
#   243,
#   253,
#   5,
#   206,
#   5,
#   155,
#   395,
#   232,
#   379,
#   319,
#   5,
#   373,
#   5,
#   5,
#   480,
#   363,
#   5,
#   5,
#   5,
#   5,
#   246,
#   5,
#   459,
#   5,
#   281,
#   374,
#   260,
#   5,
#   314,
#   5,
#   5,
# ...

# %%
# Box-plot of good, bad and neutral characters about the Total column.
plt.figure(figsize=(10,4))
plt.boxplot(data)
plt.grid(True)
plt.show()

# %% [markdown]
# # Who is the most intelligent characters ?

# %%
# Box-plot to compare the intelligence among the good, bad and neutral characters.
sns.boxplot(data=marvel, x="Alignment", y="Intelligence")
plt.grid(True)

# %% [markdown]
# # SUMMARY

# %% [markdown]
# * Startdust is the most durable superhero.

# %% [markdown]
# * Ares has the highest combat among superhero.

# %% [markdown]
# * Martain Mahunter is the best superhero.

# %% [markdown]
# * Mister Mxyzptlk is the most intelligent supervillain.

# %% [markdown]
# * Doomsday is the most durable supervillain.

# %% [markdown]
# * Superboy-Prime and  General Zod are the best supervillains.

# %% [markdown]
# * Most of the characters have the Intelligency between 1 and 10.

# %% [markdown]
# * Most of the characters have the Strength between 1 and 20.

# %% [markdown]
# * Most of the characters have the speed between 1 and 10.

# %% [markdown]
# * Most of the characters have the durability between 1 and 10.

# %% [markdown]
# * Most of the characters have the power between 0 and 10, and also there are so much characters who don't have any power means they are powerless.

# %% [markdown]
# * Most of the characters have the combat between 1 and 10.

# %% [markdown]
# * Most of the characters have the total between 1 and 10.

# %% [markdown]
# * Among good, bad and neutral characters the maximum Total is of good character.

# %% [markdown]
# * Among good, bad and neutral characters the maximum Intelligence is of bad character.
